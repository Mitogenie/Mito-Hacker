# %% [markdown]
# <h1 style="text-align:center;">MiA <span style="text-align:center;font-size: 0.5em;">0.8.8</span></h1>
# <h2 style="text-align:center;">CeMiA Toolkit <i style="font-size: 0.5em;">0.6.0</i></h2>
# <h3 style="text-align:center;">Kashatus Lab @ UVA</h3>

# %% [markdown]
# # Welcome to MiA (Mitochondrial Analyzer)
# #### MiA is part of CeMiA toolkit that enables you to quantify the segmented miotchondrial netwrk generated by Mito Miner
#
# ### <span style="color:red;">Notes:</span>
#
# This Jupyter notebook provides you with step-by-step directions to quantify your mitochondria.

# %% [markdown]
# ## 1) Import necessary libraries
# ##### Just run the following block of code, you are not expected to enter any data here.

# %%
#Base Libraries
import os
import shutil

#Core Functions
import cemia55s as cemia

# %% [markdown]
# ## 2) Locating your files
#
# <br>
# <details>
# <summary><span style="font-size:16px;font-weight: bold; color:red">Instructions</span></summary>
#
#
# #### <span style="color:red;">Interact with the code: </span> Please enter the relative address of the folder that contains your images.
#
# #### <span style="color:red;">Examples: </span>
# * Use . if the images are in the same folder as this file
# * If the folder of the images is named "test" and is located on the upper level of the current folder, the address would be ../test (Mac)
#
# #### <span style="color:red;">Note: </span>
# * It is preferred to have the folder of your images in the same folder as the current file that you are running
# * After you enetered the value in the box, you should press enter.
# * This is the address to the parent folder of where images are located.
#     * Example: If you have already used Mito Miner to segment your cells, and your cells are located in "parent_folder/output/processed/..." you should enter parent_folder here.
# </details>

# %%
address,file_list = cemia.address()
# Out:
# Where are the files located?
#
# test2

# %% [markdown]
# ## 3) Checking requirements

# %%
cell_list = os.listdir(os.path.join(address, 'output', 'processed','single_cells_binary'))                     
if len(cell_list) <= 1:
    print('It seems you dont have any images to analyze!')

# %% [markdown]
# ## 4) Name your output data filename
# ##### Just name your file here in box that appears.

# %%
output_filename = input('What is the name of output csv file?\nJust enter the name without .csv extension\nWe Will add the current date to the beginning of the file name!\n\n')
# Out:
# What is the name of output csv file?
# Just enter the name without .csv extension
# We Will add the current date to the beginning of the file name!
#
# test

# %% [markdown]
# ## 5) Quantifying all the files

# %% [markdown]
# #### Just run this block of code, and then go and enjoy your time. Running this block of code may take few hours depending on the number of images you have.

# %%
cemia.measurement(address,cell_list,output_filename)
# Out:
# r03c05f01p01multi_channel_cell6_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell6_1024binarized.tif
# /Users/ali/opt/anaconda3/lib/python3.7/site-packages/skimage/measure/_regionprops.py:250: UserWarning: regionprops and image moments (including moments, normalized moments, central moments, and inertia tensor) of 2D images will change from xy coordinates to rc coordinates in version 0.16.
# See https://scikit-image.org/docs/0.14.x/release_notes_and_installation.html#deprecations for details on how to avoid this message.
#   warn(XY_TO_RC_DEPRECATION_MESSAGE)
# /Users/ali/opt/anaconda3/lib/python3.7/site-packages/skimage/measure/_regionprops.py:260: UserWarning: regionprops and image moments (including moments, normalized moments, central moments, and inertia tensor) of 2D images will change from xy coordinates to rc coordinates in version 0.16.
# See https://scikit-image.org/docs/0.14.x/release_notes_and_installation.html#deprecations for details on how to avoid this message.
#   warn(XY_TO_RC_DEPRECATION_MESSAGE)
# r03c05f01p01multi_channel_cell3_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell3_1024binarized.tif
# r03c05f01p01multi_channel_cell7_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell7_1024binarized.tif
# r03c05f01p01multi_channel_cell19_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell19_1024binarized.tif
# r03c05f01p01multi_channel_cell2_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell2_1024binarized.tif
# r03c05f01p01multi_channel_cell4_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell4_1024binarized.tif
# r03c05f01p01multi_channel_cell5_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell5_1024binarized.tif
# r03c05f01p01multi_channel_cell17_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell17_1024binarized.tif
# r03c05f01p01multi_channel_cell9_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell9_1024binarized.tif
# r03c05f01p01multi_channel_cell12_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell12_1024binarized.tif
# r03c05f01p01multi_channel_cell16_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell16_1024binarized.tif
# r03c05f01p01multi_channel_cell8_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell8_1024binarized.tif
# r03c05f01p01multi_channel_cell22_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell22_1024binarized.tif
# r03c05f01p01multi_channel_cell13_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell13_1024binarized.tif
# r03c05f01p01multi_channel_cell21_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell21_1024binarized.tif
# r03c05f01p01multi_channel_cell10_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell10_1024binarized.tif
# r03c05f01p01multi_channel_cell24_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell24_1024binarized.tif
# r03c05f01p01multi_channel_cell14_1024binarized.tif
# Now quantifying: r03c05f01p01multi_channel_cell14_1024binarized.tif
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-584710001534> in <module>
# ----> 1 cemia.measurement(address,cell_list,output_filename)
#
# ~/Dropbox/Cancer/New CeMiA/MITO/cemia55s.py in measurement(address, cell_list, output_filename)
#    1780     detail = str(datetime.datetime.now().year) + '-' + str(datetime.datetime.now().month) + '-' + str(datetime.datetime.now().day) + '-' + output_filename
#    1781     database.drop(database.index[0],inplace=True)
# -> 1782     database.to_csv(address+'/'+detail+'.tsv', sep='\t')
#    1783
#    1784     print('Done with Measurements!\nYour data is Ready! Enjoy :)')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test2/2020-4-25-test.tsv'

# %% [markdown]
# # The End!
